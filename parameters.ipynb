# %%
import pandas as pd

# %%
df = pd.read_csv("two_stage_opamp_results.csv")
df.head()
# Out:
#         W1        L1       W3        L3       W5        L5        W6  \
# 0  17.224u  477.740n   4.040u  291.013n   2.022u  476.170n  209.827u
# 1  17.949u  257.050n   9.480u  481.833n  10.217u  421.356n  174.434u
# 2  13.587u  279.850n   8.791u  447.508n  18.414u  325.641n  167.950u
# 3  11.733u  455.873n  14.820u  269.126n  17.710u  410.639n  174.273u
# 4   4.328u  479.337n  12.380u  255.534n  16.422u  506.999n  310.311u
#
#          L6        W7        L7       IB      CC       Gain  Gain_Phase  \
# 0  321.736n   97.248u  218.309n  29.508u  0.877p  86.381980   91.260173
# 1  244.790n   81.521u  516.117n  23.099u  2.404p  46.395266  177.481494
# 2  219.554n   75.882u  241.831n  25.523u  1.217p  76.066043   91.266877
# 3  238.014n  119.366u  293.891n  17.896u  1.541p  82.522393   93.107568
# 4  318.447n   82.590u  450.226n  16.458u  1.527p  71.626556   98.207259
#
#             UGBW      PM_db  PM_PH
# 0  208540.015297  39.015976    0.0
# 1   47525.989615  39.057700    0.0
# ...

# %%
para = ["W1","L1","W3","L3","W5","L5","W6"	,"L6","W7","L7","IB","CC"]

# %%
df_new = df[para]
df_new.head()
# Out:
#         W1        L1       W3        L3       W5        L5        W6  \
# 0  17.224u  477.740n   4.040u  291.013n   2.022u  476.170n  209.827u
# 1  17.949u  257.050n   9.480u  481.833n  10.217u  421.356n  174.434u
# 2  13.587u  279.850n   8.791u  447.508n  18.414u  325.641n  167.950u
# 3  11.733u  455.873n  14.820u  269.126n  17.710u  410.639n  174.273u
# 4   4.328u  479.337n  12.380u  255.534n  16.422u  506.999n  310.311u
#
#          L6        W7        L7       IB      CC
# 0  321.736n   97.248u  218.309n  29.508u  0.877p
# 1  244.790n   81.521u  516.117n  23.099u  2.404p
# 2  219.554n   75.882u  241.831n  25.523u  1.217p
# 3  238.014n  119.366u  293.891n  17.896u  1.541p
# 4  318.447n   82.590u  450.226n  16.458u  1.527p

# %%
df_new.to_csv("parameters.csv", index=False)
